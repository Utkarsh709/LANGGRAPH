# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model=ChatOpenAI()

# %%
#create state

class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState)->LLMState:
    #extract question from state
    question=state['question']
    
    #form a prompt
    prompt=f"answer the following question {question}"
    
    #ask that question to llm
    answer=model.invoke(prompt).content
    
    #update the answer in the state
    state['answer']=answer
    
    return state

# %%
#create graph
graph=StateGraph(LLMState)

#add node
graph.add_node('llm_qa',llm_qa)

#add edge
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

#compile
workflow=graph.compile()

# %%
#execute
initial_state={'question':'how far is moon from earth?'}
final_state=workflow.invoke(initial_state)
print(final_state)
# Out:
# {'question': 'how far is moon from earth?', 'answer': 'The average distance from the Earth to the Moon is about 384,400 kilometers (238,855 miles).'}
